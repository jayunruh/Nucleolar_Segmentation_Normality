# %%
#this notebook compares Fiji(java) and python measurements
#they are not identical but are very similar
import pandas as pd
import matplotlib.pyplot as plt

# %%
newdf=pd.read_csv('img_measurements.csv',index_col=0)
newdf.head()
# Out:
#    id  nuclear_id  nuclear_area  nuclear_avg  nuclear_stdev  number_nucleoli  \
# 0   0           1        2410.0  1522.423268    1455.759119                2
# 1   1           1        2410.0  1522.423268    1455.759119                2
# 2   2           2        3006.0  1556.982159    1696.827323                5
# 3   3           2        3006.0  1556.982159    1696.827323                5
# 4   4           2        3006.0  1556.982159    1696.827323                5
#
#    nucleolar_area  nucleolar_avg  nucleolar_stdev  third_nucavg  \
# 0            26.0    4929.816548       755.623877   1296.417575
# 1           135.0    6465.998136      1627.561479   1296.417575
# 2            10.0    6076.138290       607.914783   1403.773721
# 3            29.0    7617.586642      1592.930798   1403.773721
# 4            23.0    7103.205879      1397.099696   1403.773721
#
#    third_nucstdev  third_nuclavg  third_nuclstdev
# 0     2285.924745    6297.444119      1026.167695
# ...

# %%
olddf=pd.read_csv('java_outputs/003003-1-001001001.xls',sep='\t')
olddf.head()
# Out:
#     id  nuclear_id  nuclear_area  nuclear_avg  nuclear_stdev  number_nucleoli  \
# 0  1.0         1.0        2623.0    855.06036      1319.6732              2.0
# 1  2.0         1.0        2623.0    855.06036      1319.6732              2.0
# 2  3.0         2.0        2925.0   1036.40430      1615.7980              5.0
# 3  4.0         2.0        2925.0   1036.40430      1615.7980              5.0
# 4  5.0         2.0        2925.0   1036.40430      1615.7980              5.0
#
#    nucleolar_area  nucleolar_avg  nucleolar_stdev  nucleolar_circularity  \
# 0            21.0      4228.5776        662.08734               0.976991
# 1           121.0      5963.5522       1441.37400               0.865623
# 2             7.0      5564.8643        541.13870               0.933319
# 3            24.0      7245.8380       1416.78530               0.912467
# 4            23.0      6674.8047       1468.14800               0.925578
#
# ...

# %%
plt.plot(newdf['nuclear_area'])
plt.plot(olddf['nuclear_area'])

# %%
plt.plot(newdf['nuclear_avg'])
plt.plot(olddf['nuclear_avg'])
plt.ylim(0,3000)
# Out:
# (0.0, 3000.0)

# %%
plt.plot(newdf['number_nucleoli'])
plt.plot(olddf['number_nucleoli'])

# %%
plt.plot(newdf['nucleolar_area'])
plt.plot(olddf['nucleolar_area'])

# %%
plt.plot(newdf['nucleolar_avg'])
plt.plot(olddf['nucleolar_avg'])

# %%
plt.plot(newdf['third_nuclavg'])
plt.plot(olddf['third_nuclavg'])
